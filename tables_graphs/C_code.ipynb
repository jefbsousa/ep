# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("../C/results_1A.csv", sep=";", header=None, 
                 names=['Método', 'N', 'núm. iterações', 'tempo(seg)', 'erro máx'])

# %%
df
# Out:
#           Método    N  núm. iterações  tempo(seg)  erro máx
# 0         Jacobi    8             121    0.000188  0.000280
# 1         Jacobi   16             424    0.002650  0.000889
# 2         Jacobi   32            1415    0.032624  0.004099
# 3         Jacobi   64            4517    0.367545  0.016576
# 4         Jacobi  128           13473    4.390553  0.066375
# 5         Jacobi  256           35490   45.510036  0.265548
# 6   Gauss-Seidel    8              67    0.000121  0.000405
# 7   Gauss-Seidel   16             233    0.001322  0.000396
# 8   Gauss-Seidel   32             786    0.017955  0.002029
# 9   Gauss-Seidel   64            2560    0.219277  0.008267
# 10  Gauss-Seidel  128            7914    2.612526  0.033178
# 11  Gauss-Seidel  256           22399   29.368853  0.132794
# 12           SOR    8              21    0.000040  0.000478
# 13           SOR   16              40    0.000243  0.000109
# 14           SOR   32              78    0.001749  0.000109
# ...

# %%
df[df['Método'] == 'Jacobi'].plot.line(x='N', y='tempo(seg)')
